# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/feynn labs intership/sigma_cabs.csv')

# %%
len(df)
# Out:
# 131662

# %%
print(df.shape)
# Out:
# (131662, 14)

# %%
df.head(10)
# Out:
#        Trip_ID  Trip_Distance Type_of_Cab  Customer_Since_Months  \
# 0  T0005689460           6.77           B                    1.0
# 1  T0005689461          29.47           B                   10.0
# 2  T0005689464          41.58         NaN                   10.0
# 3  T0005689465          61.56           C                   10.0
# 4  T0005689467          54.95           C                   10.0
# 5  T0005689469          19.06           E                   10.0
# 6  T0005689470          29.72           E                   10.0
# 7  T0005689472          18.44           B                    2.0
# 8  T0005689473         106.80           C                    3.0
# 9  T0005689474         107.19           D                    5.0
#
#    Life_Style_Index Confidence_Life_Style_Index Destination_Type  \
# 0           2.42769                           A                A
# 1           2.78245                           B                A
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131662 entries, 0 to 131661
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Trip_ID                      131662 non-null  object
#  1   Trip_Distance                131662 non-null  float64
#  2   Type_of_Cab                  111452 non-null  object
#  3   Customer_Since_Months        125742 non-null  float64
#  4   Life_Style_Index             111469 non-null  float64
#  5   Confidence_Life_Style_Index  111469 non-null  object
#  6   Destination_Type             131662 non-null  object
#  7   Customer_Rating              131662 non-null  float64
#  8   Cancellation_Last_1Month     131662 non-null  int64
#  9   Var1                         60632 non-null   float64
#  10  Var2                         131662 non-null  int64
#  11  Var3                         131662 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Trip_ID                            0
# Trip_Distance                      0
# Type_of_Cab                    20210
# Customer_Since_Months           5920
# Life_Style_Index               20193
# Confidence_Life_Style_Index    20193
# Destination_Type                   0
# Customer_Rating                    0
# Cancellation_Last_1Month           0
# Var1                           71030
# Var2                               0
# Var3                               0
# Gender                             0
# Surge_Pricing_Type                 0
# dtype: int64

# %%
df1=df.dropna()

# %%
df1.isna().sum()
# Out:
# Trip_ID                        0
# Trip_Distance                  0
# Type_of_Cab                    0
# Customer_Since_Months          0
# Life_Style_Index               0
# Confidence_Life_Style_Index    0
# Destination_Type               0
# Customer_Rating                0
# Cancellation_Last_1Month       0
# Var1                           0
# Var2                           0
# Var3                           0
# Gender                         0
# Surge_Pricing_Type             0
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        # For object type columns, replace null values with the mode
        df[col].fillna(df[col].mode()[0], inplace=True)
    else:
        # For numeric type columns, replace null values with the mean
        df[col].fillna(df[col].mean(), inplace=True)

df.head(10)
# Out:
#        Trip_ID  Trip_Distance Type_of_Cab  Customer_Since_Months  \
# 0  T0005689460           6.77           B                    1.0
# 1  T0005689461          29.47           B                   10.0
# 2  T0005689464          41.58           B                   10.0
# 3  T0005689465          61.56           C                   10.0
# 4  T0005689467          54.95           C                   10.0
# 5  T0005689469          19.06           E                   10.0
# 6  T0005689470          29.72           E                   10.0
# 7  T0005689472          18.44           B                    2.0
# 8  T0005689473         106.80           C                    3.0
# 9  T0005689474         107.19           D                    5.0
#
#    Life_Style_Index Confidence_Life_Style_Index Destination_Type  \
# 0          2.427690                           A                A
# 1          2.782450                           B                A
# ...

# %%
df.isna().sum()
# Out:
# Trip_ID                        0
# Trip_Distance                  0
# Type_of_Cab                    0
# Customer_Since_Months          0
# Life_Style_Index               0
# Confidence_Life_Style_Index    0
# Destination_Type               0
# Customer_Rating                0
# Cancellation_Last_1Month       0
# Var1                           0
# Var2                           0
# Var3                           0
# Gender                         0
# Surge_Pricing_Type             0
# dtype: int64

# %%
# a pairplot of numerical columns
#sns.pairplot(df.select_dtypes(include=['float64', 'int64']))
#plt.title('Pairplot of Numerical Columns')
#plt.show()

# %%
#histogram of Trip Distance:

plt.hist(df['Trip_Distance'], bins=20)
plt.xlabel('Trip Distance')
plt.ylabel('Count')
plt.title('Histogram of Trip Distance')
plt.show()

# %%
#HISTOGRAM of Trip Distance:
import matplotlib.pyplot as plt

# Create a histogram of the Trip Distance column
plt.hist(df['Trip_Distance'], bins=20)
plt.xlabel('Trip Distance')
plt.ylabel('Frequency')
plt.title('Distribution of Trip Distance')
plt.show()

# %%
#Bar chart of Type of Cab
import seaborn as sns

sns.countplot(x='Type_of_Cab', data=df,hue=df.Type_of_Cab)
plt.xlabel('Type of Cab')
plt.ylabel('Count')
plt.title('Number of Trips by Type of Cab')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Cancellation_Last_1Month', hue='Gender', data=df)
plt.title('Cancellation Last 1 Month by Gender')
# Out:
# Text(0.5, 1.0, 'Cancellation Last 1 Month by Gender')

# %%
#Count plot of Destination_type
sns.countplot(x='Destination_Type', data=df)
# Out:
# <Axes: xlabel='Destination_Type', ylabel='count'>

# %%
#Box plot of Customer Rating by Surge Pricing Type:

sns.boxplot(x='Surge_Pricing_Type', y='Customer_Rating', data=df)
plt.xlabel('Surge Pricing Type')
plt.ylabel('Customer Rating')
plt.title('Distribution of Customer Rating by Surge Pricing Type')
plt.show()

# %%
#Boxplot of Customer Rating by Gender:

sns.boxplot(x='Gender', y='Customer_Rating', data=df)
plt.title('Customer Rating by Gender')
plt.show()

# %%
#Scatter plot of Customer Rating vs. Trip Distance:

plt.scatter(df['Customer_Rating'], df['Trip_Distance'])
plt.xlabel('Customer Rating')
plt.ylabel('Trip Distance')
plt.title('Customer Rating vs. Trip Distance')
plt.show()

# %%
#Heatmap of correlation matrix of numerical variables

num_vars = ['Trip_Distance', 'Customer_Since_Months', 'Life_Style_Index', 'Customer_Rating', 'Cancellation_Last_1Month', 'Var1', 'Var2', 'Var3', 'Surge_Pricing_Type']
corr_matrix = df[num_vars].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix of Numerical Variables')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Numerical Variables')

# %%
#Pie chart of Cancellation Last 1 Month:

cancelled = df['Cancellation_Last_1Month'].value_counts()
plt.pie(cancelled, labels=cancelled.index, autopct='%1.1f%%')
plt.title('Percentage of Cancellation Last 1 Month')
plt.show()

# %%
#histplots
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
sns.histplot(data=df, x="Trip_Distance", kde=True)

plt.subplot(2, 2, 2)
sns.histplot(data=df, x="Life_Style_Index", kde=True)

plt.subplot(2, 2, 3)
sns.histplot(data=df, x="Cancellation_Last_1Month", kde=True)

plt.subplot(2, 2, 4)
sns.histplot(data=df, x="Surge_Pricing_Type", kde=True)

plt.tight_layout()

plt.show()

# %%
#boxplots
plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
sns.boxplot(data=df, x="Trip_Distance")

plt.subplot(2, 2, 2)
sns.boxplot(data=df, x="Customer_Since_Months")

plt.subplot(2, 2, 3)
sns.boxplot(data=df, x="Customer_Rating")

plt.subplot(2, 2, 4)
sns.boxplot(data=df, x="Life_Style_Index")

plt.tight_layout()
plt.show()

# %%
#Violin plots
plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
sns.violinplot(data=df, x="Trip_Distance")

plt.subplot(2, 2, 2)
sns.violinplot(data=df, x="Customer_Since_Months")

plt.subplot(2, 2, 3)
sns.violinplot(data=df, x="Customer_Rating")

plt.subplot(2, 2, 4)
sns.violinplot(data=df, x="Life_Style_Index")

#plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Type_of_Cab', y='Trip_Distance', data=df)
plt.title('Trip Distance by Cab Type')
# Out:
# Text(0.5, 1.0, 'Trip Distance by Cab Type')

# %%
plt.figure(figsize=(15,10))
sns.violinplot(x='Surge_Pricing_Type', y='Destination_Type', data=df)
plt.title('Surge Pricing Type by Destination Type')
# Out:
# Text(0.5, 1.0, 'Surge Pricing Type by Destination Type')

# %%
df_1 = df.drop(columns=["Trip_ID"])
numerical_cols = df_1.select_dtypes(include=['float64','int64']).columns.tolist()
categorical_cols = df_1.select_dtypes(include=['object']).columns.tolist()

# %%
numerical_cols
# Out:
# ['Trip_Distance',
#  'Customer_Since_Months',
#  'Life_Style_Index',
#  'Customer_Rating',
#  'Cancellation_Last_1Month',
#  'Var1',
#  'Var2',
#  'Var3',
#  'Surge_Pricing_Type']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_normalized = pd.DataFrame()
df_normalized[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
df_normalized.head()
# Out:
#    Trip_Distance  Customer_Since_Months  Life_Style_Index  Customer_Rating  \
# 0      -1.466568              -1.415378     -1.801959e+00         1.076346
# 1      -0.577167               1.123841     -9.440728e-02         0.612378
# 2      -0.102689               1.123841      2.137517e-15         0.664638
# 3       0.680141               1.123841      2.137517e-15         0.616202
# 4       0.421157               1.123841      1.118919e+00         0.563942
#
#    Cancellation_Last_1Month      Var1      Var2      Var3  Surge_Pricing_Type
# 0                 -0.754502 -1.634493 -1.043456 -1.304086           -0.210994
# 1                 -0.754502 -1.769560  0.962110  0.250555           -0.210994
# 2                  1.173106  0.000000  0.962110  0.164186           -0.210994
# 3                 -0.754502  0.000000  0.159884 -0.094921            1.143724
# 4                  3.100714 -0.891624 -0.441786  2.323410           -0.210994

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_encoded = pd.DataFrame()
df_encoded["Type_of_Cab"]=le.fit_transform(df["Type_of_Cab"])
df_encoded["Confidence_Life_Style_Index"] =le.fit_transform(df["Confidence_Life_Style_Index"])
df_encoded["Destination_Type"]=le.fit_transform(df["Destination_Type"])
df_encoded["Gender"]=le.fit_transform(df["Gender"])
df_encoded = df_encoded[["Type_of_Cab","Destination_Type","Gender","Confidence_Life_Style_Index"]]

df_encoded.head()
# Out:
#    Type_of_Cab  Destination_Type  Gender  Confidence_Life_Style_Index
# 0            1                 0       0                            0
# 1            1                 0       1                            1
# 2            1                 4       1                            1
# 3            2                 0       1                            1
# 4            2                 0       1                            1

# %%
# Concatenate vertically
df_final = pd.concat([df_normalized,df_encoded], axis=1)

# %%
df_final.head()
# Out:
#    Trip_Distance  Customer_Since_Months  Life_Style_Index  Customer_Rating  \
# 0      -1.466568              -1.415378     -1.801959e+00         1.076346
# 1      -0.577167               1.123841     -9.440728e-02         0.612378
# 2      -0.102689               1.123841      2.137517e-15         0.664638
# 3       0.680141               1.123841      2.137517e-15         0.616202
# 4       0.421157               1.123841      1.118919e+00         0.563942
#
#    Cancellation_Last_1Month      Var1      Var2      Var3  Surge_Pricing_Type  \
# 0                 -0.754502 -1.634493 -1.043456 -1.304086           -0.210994
# 1                 -0.754502 -1.769560  0.962110  0.250555           -0.210994
# 2                  1.173106  0.000000  0.962110  0.164186           -0.210994
# 3                 -0.754502  0.000000  0.159884 -0.094921            1.143724
# 4                  3.100714 -0.891624 -0.441786  2.323410           -0.210994
#
# ...

# %%
#correlation matrix
corr_matrix = df_final.corr()
corr_matrix
# Out:
#                              Trip_Distance  Customer_Since_Months  \
# Trip_Distance                     1.000000               0.114340
# Customer_Since_Months             0.114340               1.000000
# Life_Style_Index                  0.468367               0.119154
# Customer_Rating                  -0.054654              -0.049001
# Cancellation_Last_1Month         -0.007686              -0.006187
# Var1                             -0.030662              -0.006700
# Var2                              0.200456               0.041766
# Var3                              0.231706               0.110830
# Surge_Pricing_Type                0.135928               0.027202
# Type_of_Cab                       0.067647               0.009622
# Destination_Type                 -0.171064              -0.054814
# Gender                            0.002173               0.001327
# Confidence_Life_Style_Index       0.224798               0.035793
#
# ...

# %%
least_corr_var = corr_matrix.abs().sum().idxmin()

print("The least correlated variable is:", least_corr_var)
# Out:
# The least correlated variable is: Gender

# %% [markdown]
# #dropping  var1 column as it has very low correlation of 	-0.005231

# %%
df_numeric = df_final[numerical_cols]
df_numeric = df_numeric.drop('Var1', axis=1)

# %%
# Draw boxplots for all numerical columns
fig = plt.figure(figsize=(20,7))
sns.boxplot(data=df_numeric)
# Out:
# <Axes: >

# %% [markdown]
# #**Removing outliers**
# df_N_NO= df_numerical data frame with no outliers

# %%
Q1 = df_numeric.quantile(0.25)
Q3 = df_numeric.quantile(0.70)
IQR = Q3 - Q1
df_N_NO = df_numeric[~((df_numeric < (Q1 - 1.5 * IQR)) |(df_numeric > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Draw boxplots for all numerical columns
fig = plt.figure(figsize=(20,7))
sns.boxplot(data=df_N_NO)
# Out:
# <Axes: >

# %%
print(df_numeric.shape)
# Out:
# (131662, 8)

# %%
print(df_N_NO.shape)
# Out:
# (101994, 8)

# %% [markdown]
# #k means clustering for 3 columns

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Drop non-numeric columns
#df_numeric = df_N_NO[numerical_cols]



# Perform KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=0)
clusters = kmeans.fit_predict(df_numeric)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Visualize the clusters

from mpl_toolkits.mplot3d import Axes3D

#visulalizing the plot for 	Trip_Distance	Customer_Since_Months	Life_Style_Index

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_numeric.values[:, 0], df_numeric.values[:, 1], df_numeric.values[:, 2], c=clusters, cmap='viridis')
ax.set_xlabel(numerical_cols[0])
ax.set_ylabel(numerical_cols[1])
ax.set_zlabel(numerical_cols[2])
plt.show()

# %%
#visulalizing the plot for 	Customer_Rating	Cancellation_Last_1Month	Var3

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_numeric.values[:, 3], df_numeric.values[:, 4], df_numeric.values[:, 6], c=clusters, cmap='plasma')
ax.set_xlabel(numerical_cols[3])
ax.set_ylabel(numerical_cols[4])
ax.set_zlabel(numerical_cols[6])
plt.show()

# %% [markdown]
# #k means clustering for two columns

# %%
df_kmc = df_N_NO[["Trip_Distance","Life_Style_Index"]]

# %%
inertia = []
##higher inertia is not good
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=0,n_init=1)
    kmeans.fit(df_kmc)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of squared distances')
plt.show()
print(inertia)
# Out:
# [133472.47548879494, 71019.2857513485, 48163.56716552141, 37149.9249509709, 29217.510186530653, 25329.037319553616, 22059.47983756316, 19452.866745225798, 16519.68797377058, 14835.907519295968]

# %% [markdown]
# **as the inertia is for number of clusters above 6, lets take n_clusters=6**

# %%
#Forming clusters on various parameters using Kmeans and Hierarchical clustering:[groups customers with similar behaviour in one cluster]

from sklearn.cluster import KMeans
kmc = KMeans(n_clusters=6,n_init=1)
model_kmc = kmc.fit(df_kmc)
model_kmc.labels_
# Out:
# array([5, 1, 2, ..., 4, 4, 4], dtype=int32)

# %%
fig = plt.figure(figsize=(10, 8))
plt.scatter(df_N_NO["Trip_Distance"],df_N_NO.Life_Style_Index,c=model_kmc.labels_)

# %%
# Calculate metrics
from sklearn.metrics import silhouette_score
inertia = kmeans.inertia_
silhouette = silhouette_score(df_kmc,model_kmc.labels_)

print('Inertia:', inertia)
print('Silhouette score:', silhouette)
# Out:
# Inertia: 14835.907519295968
# Silhouette score: 0.3733336007588392

# %% [markdown]
# #Applying pca with 2 components

# %%
from sklearn.decomposition import PCA

# Apply PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(df_final)

# Create a new DataFrame with the principal components
df_pca = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

# Visualize the first two principal components
plt.scatter(df_pca['PC1'], df_pca['PC2'], c=df_pca['PC1'], cmap='PuRd')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
df_pca.head()
# Out:
#         PC1       PC2
# 0 -0.175221 -3.283565
# 1 -1.031841 -0.050944
# 2  2.821884  1.252343
# 3 -1.087845  0.258809
# 4 -1.237786  2.026508

# %%
# Perform KMeans clustering
kmeans = KMeans(n_clusters=4, random_state=0)
clusters = kmeans.fit_predict(df_pca)

# Visualize the clusters
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
ax.scatter(df_pca.values[:, 0], df_pca.values[:, 1], c=clusters, cmap='viridis')
ax.set_xlabel('PCA Component 1')
ax.set_ylabel('PCA Component 2')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Calculate metrics
from sklearn.metrics import silhouette_score
inertia = kmeans.inertia_
silhouette = silhouette_score(df_pca, clusters)

print('Inertia:', inertia)
print('Silhouette score:', silhouette)
# Out:
# Inertia: 192276.1693878618
# Silhouette score: 0.4461127405408211

# %% [markdown]
# #applying elbow method to find out the best number of clusters

# %%
inertia = []
##higher inertia is not good
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=0,n_init=1)
    kmeans.fit(df_kmc)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of squared distances')
plt.show()
print(inertia)
# Out:
# [133472.47548879494, 71019.2857513485, 48163.56716552141, 37149.9249509709, 29217.510186530653, 25329.037319553616, 22059.47983756316, 19452.866745225798, 16519.68797377058, 14835.907519295968]

# %% [markdown]
# #applying pca with 3 components

# %%
from sklearn.decomposition import PCA

# Apply PCA
pca2 = PCA(n_components=3)
principal_components2 = pca2.fit_transform(df_N_NO)

# Create a new DataFrame with the principal components
df_pca2 = pd.DataFrame(data=principal_components2, columns=['PC1', 'PC2', 'PC3'])

# %% [markdown]
# # Visualize the three principal components

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_pca2['PC1'], df_pca2['PC2'], df_pca2['PC3'], c=df_pca2['PC3'], cmap='viridis')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
plt.show()

# %% [markdown]
# #applying clustering with data after pca

# %%
# Perform KMeans clustering
kmeans2 = KMeans(n_clusters=3, random_state=0)
clusters2 = kmeans2.fit_predict(df_pca2)


# Visualize the clusters
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#visulalizing the plot for 	Customer_Rating	Cancellation_Last_1Month	Var1



# Visualize the first two principal components
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_pca2.values[:, 0], df_pca2.values[:, 1],df_pca2.values[:, 2], c=clusters2, cmap='viridis')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Calculate metrics
from sklearn.metrics import silhouette_score
inertia = kmeans.inertia_
silhouette = silhouette_score(df_pca2, clusters2)

print('Inertia:', inertia)
print('Silhouette score:', silhouette)
# Out:
# Inertia: 14835.907519295968
# Silhouette score: 0.23688338553475774
